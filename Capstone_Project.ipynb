# %% [markdown]
# <a id="ref1"></a>
# # Capstone Project Assignment 1

# %% [markdown]
# ### This notebook will be mainly used for the capstone project.

# %%
#2. Import pandas Library
import pandas as pd
print("Pandas library imported",pd.__path__)
# Out:
# Pandas library imported ['/opt/conda/envs/Python36/lib/python3.6/site-packages/pandas']

# %%
#3. Import numpy Library

import numpy as np
print("Numpy library imported",np.__path__)
# Out:
# Numpy library imported ['/opt/conda/envs/Python36/lib/python3.6/site-packages/numpy']

# %%
#Print the following the statement: Hello Capstone Project Course! 

print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
